# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolly-abreu/Nick-s-Bakery/blob/main/aceleracao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formula da Velocidade Média

# %%
def calcVelMedia(deltaS, deltaT):
  velMedia = (deltaS / deltaT)
  return velMedia

# %% [markdown]
# teste de serviço: velocidade media

# %%
print('Velocidade Média: ',calcVelMedia(50, 4))
# Out:
# Velocidade Média:  12.5

# %% [markdown]
# # Fórmula da aceleração

# %%
def calcaceleracao(velocidade, tempo):
  aceleracao = (velocidade / tempo)
  return aceleracao

# %%
print('Aceleração media: ', calcaceleracao(30, 2))
# Out:
# Aceleração media:  15.0

# %% [markdown]
# # Fórmulas do Movimento Uniforme (MU)

# %% [markdown]
# ## Função horária do deslocamento

# %% [markdown]
# # Fórmulas do Movimento Uniformemente Variado (MUV)

# %% [markdown]
# ## Função horária da posição

# %% [markdown]
# ## Equação de Torricelli

# %%
import math
def calctorricelli(vzero, acel, desloc):
    t = 2 * acel * desloc
    vfinal = t + vzero
    res = round(math.sqrt(vfinal), 2)
    return res

# %%
print('Velocidade final',calctorricelli(50, 4, 20))
# Out:
# Velocidade final 14.49

# %% [markdown]
# # Fórmula do movimento vertical

# %% [markdown]
# ## Equação de Torricelli para lançamento vertical

# %% [markdown]
# ## Velocidade vertical em função do tempo

# %% [markdown]
# ## Posição vertical em função do tempo
